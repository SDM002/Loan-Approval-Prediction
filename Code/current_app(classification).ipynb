# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Current_app dataset
file_path1 = "/content/drive/MyDrive/UP2205708 (Major Project)MSc Data Analytics/Report/filtered_current_app.csv"
current_app = pd.read_csv(file_path1, header='infer')

# %%
current_app.shape
# Out:
# (291057, 23)

# %%
current_app.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER  CNT_CHILDREN  \
# 0      100002       1         Cash loans           M             0
# 1      100003       0         Cash loans           F             0
# 2      100004       0    Revolving loans           M             0
# 3      100006       0         Cash loans           F             0
# 4      100007       0         Cash loans           M             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE  \
# 0          202500.0    406597.5      24700.5         351000.0   Unaccompanied
# 1          270000.0   1293502.5      35698.5        1129500.0          Family
# 2           67500.0    135000.0       6750.0         135000.0   Unaccompanied
# 3          135000.0    312682.5      29686.5         297000.0   Unaccompanied
# 4          121500.0    513000.0      21865.5         513000.0   Unaccompanied
#
#    ...  NAME_HOUSING_TYPE DAYS_EMPLOYED OCCUPATION_TYPE CNT_FAM_MEMBERS  \
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Display column names
print("\nColumns in previous_app dataset:")
print(current_app.columns)
# Out:
# Columns in previous_app dataset:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
#        'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'DAYS_EMPLOYED', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY',
#        'WEEKDAY_APPR_PROCESS_START', 'REG_CITY_NOT_WORK_CITY',
#        'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE'],
#       dtype='object')

# %% [markdown]
# # **Data Visualisation**

# %%
# Count the occurrences of each unique value in the TARGET column
TARGET_counts = current_app['TARGET'].value_counts()

# Display the content of TARGET_counts
print(TARGET_counts)

# Define the labels for the pie chart and bar graph
labels = ['Non-defaulters', 'Defaulters']

# Create a pie chart with a safe figure size
plt.figure(figsize=(4, 4))  # Increased figure size slightly for better visibility

# Plot the pie chart
plt.pie(
    TARGET_counts,
    labels=labels,  # Use the custom labels
    autopct='%1.1f%%',
    startangle=90,
    colors=['#ff9999','#66b3ff'],
    explode=(0.05, 0)
)
plt.title('Pie Chart of TARGET Distribution')
plt.show()

# Plot a bar graph
plt.figure(figsize=(4, 4))
sns.barplot(x=labels, y=TARGET_counts.values, palette="viridis")
plt.title('Bar Graph of TARGET')
plt.xlabel('TARGET')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# TARGET
# 0    267212
# 1     23845
# Name: count, dtype: int64

# %%
# Replace 'XNA' with 'Not prefer to say' in the CODE_GENDER column
current_app['CODE_GENDER'].replace('XNA', 'Not prefer to say', inplace=True)

# Create a count plot for CODE_GENDER vs. TARGET
plt.figure(figsize=(6, 4))
sns.countplot(data=current_app, x='CODE_GENDER', hue='TARGET', palette="viridis")

# Customize the plot
plt.title('Count Plot of Gender vs. Target (Defaulters and Non-defaulters)')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Target', labels=['Non-defaulters', 'Defaulters'])

# Show the plot
plt.show()

# %%
# Create a count plot for NAME_TYPE_SUITE vs. TARGET
plt.figure(figsize=(10, 6))
sns.countplot(data=current_app, x='NAME_TYPE_SUITE', hue='TARGET', palette="viridis")

# Customize the plot
plt.title('Count Plot of Name Type Suite vs. Target (Defaulters and Non-defaulters)')
plt.xlabel('Name Type Suite')
plt.ylabel('Count')
plt.legend(title='Target', labels=['Non-defaulters', 'Defaulters'])
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %%
# Create a count plot for NAME_TYPE_SUITE vs. TARGET
plt.figure(figsize=(10, 6))
sns.countplot(data=current_app, x='NAME_INCOME_TYPE', hue='TARGET', palette="viridis")

# Customize the plot
plt.title('Count Plot of Name Income Type vs. Target (Defaulters and Non-defaulters)')
plt.xlabel('NAME_INCOME_TYPE')
plt.ylabel('Count')
plt.legend(title='Target', labels=['Non-defaulters', 'Defaulters'])
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %%
# Create a count plot for NAME_EDUCATION_TYPE vs. TARGET
plt.figure(figsize=(10, 6))
sns.countplot(data=current_app, x='NAME_EDUCATION_TYPE', hue='TARGET', palette="cubehelix")

# Customize the plot
plt.title('Count Plot of Name Type Suite vs. Target (Defaulters and Non-defaulters)')
plt.xlabel('NAME_EDUCATION_TYPE')
plt.ylabel('Count')
plt.legend(title='Target', labels=['Non-defaulters', 'Defaulters'])
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %%
# Create a count plot for NAME_FAMILY_STATUS vs. TARGET
plt.figure(figsize=(10, 6))
sns.countplot(data=current_app, x='NAME_FAMILY_STATUS', hue='TARGET', palette="Blues")

# Customize the plot
plt.title('Count Plot of NAME_FAMILY_STATUS vs. Target (Defaulters and Non-defaulters)')
plt.xlabel('NAME_FAMILY_STATUS')
plt.ylabel('Count')
plt.legend(title='Target', labels=['Non-defaulters', 'Defaulters'])
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %%
# Create a count plot for NAME_FAMILY_STATUS vs. TARGET
plt.figure(figsize=(10, 6))
sns.countplot(data=current_app, x='OCCUPATION_TYPE', hue='TARGET', palette="viridis")

# Customize the plot
plt.title('Count Plot of OCCUPATION_TYPE vs. Target (Defaulters and Non-defaulters)')
plt.xlabel('OCCUPATION_TYPE')
plt.ylabel('Count')
plt.legend(title='Target', labels=['Non-defaulters', 'Defaulters'])
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Show the plot
plt.show()

# %%
# Create a DataFrame for the heatmap
contract_target_matrix = current_app.groupby(['NAME_CONTRACT_TYPE', 'TARGET']).size().unstack().fillna(0)

# Plot a heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(contract_target_matrix, annot=True, fmt='d', cmap='viridis')

# Customize the plot
plt.title('Heatmap of Contract Type vs. Target (Defaulters and Non-defaulters)')
plt.xlabel('Target')
plt.ylabel('Contract Type')
plt.xticks(ticks=[0, 1], labels=['Non-defaulters', 'Defaulters'])

# Show the plot
plt.show()

# %%
# Step 1: Bin the Income Data
bins = [0, 50000, 100000, 150000, 200000, 1000000]  # Custom bins for income
labels = ['Low', 'Lower-Mid', 'Mid', 'Upper-Mid', 'High']  # Labels for the bins

current_app['Income_Category'] = pd.cut(current_app['AMT_INCOME_TOTAL'], bins=bins, labels=labels)

# Step 2: Create a Bar Plot
plt.figure(figsize=(8, 6))
sns.countplot(data=current_app, x='Income_Category', hue='TARGET', palette='viridis')

# Customize the plot
plt.title('Bar Plot of Income Categories vs. Target (Defaulters and Non-defaulters)')
plt.xlabel('Income Category')
plt.ylabel('Count')
plt.legend(title='TARGET', labels=['Non-defaulters', 'Defaulters'])
plt.grid(True, linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# Aggregate the data to get the mean AMT_CREDIT for each TARGET category
mean_credit_by_target = current_app.groupby('TARGET')['AMT_CREDIT'].mean().reset_index()

# Create a bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x='TARGET', y='AMT_CREDIT', data=mean_credit_by_target, palette="viridis")

# Customize the plot
plt.title('Mean AMT_CREDIT by TARGET')
plt.xlabel('TARGET')
plt.ylabel('Mean AMT_CREDIT')
plt.xticks(ticks=[0, 1], labels=['Non-defaulters (0)', 'Defaulters (1)'])

# Show the plot
plt.show()

# %%
# Calculate percentiles for income ranges
percentiles = np.percentile(current_app['AMT_INCOME_TOTAL'].dropna(), [0, 25, 50, 75, 100])
percentile_labels = ['0-25%', '25%-50%', '50%-75%', '75%-100%']

# Create a new column for income ranges based on percentiles
current_app['INCOME_RANGE'] = pd.cut(current_app['AMT_INCOME_TOTAL'], bins=percentiles, labels=percentile_labels, include_lowest=True)

# Filter data for non-defaulters and defaulters
non_defaulters = current_app[current_app['TARGET'] == 0]
defaulters = current_app[current_app['TARGET'] == 1]

# Aggregate data by income range and calculate the mean AMT_ANNUITY
non_defaulters_summary = non_defaulters.groupby('INCOME_RANGE')['AMT_ANNUITY'].mean().reset_index()
defaulters_summary = defaulters.groupby('INCOME_RANGE')['AMT_ANNUITY'].mean().reset_index()


# Add a TARGET column for grouping
non_defaulters_summary['TARGET'] = 'Non-Defaulters'
defaulters_summary['TARGET'] = 'Defaulters'
combined_summary = pd.concat([non_defaulters_summary, defaulters_summary])

# Create the bar plot
plt.figure(figsize=(6, 4))
sns.barplot(x='INCOME_RANGE', y='AMT_ANNUITY', hue='TARGET', data=combined_summary, palette={'Non-Defaulters': 'blue', 'Defaulters': 'red'})
plt.title('Average AMT_ANNUITY by Income Range for Non-Defaulters and Defaulters')
plt.xlabel('Income Range')
plt.ylabel('Average AMT_ANNUITY')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='TARGET')
plt.show()

# %%
# Summary Statistics
print("\nSummary Statistics for INCOME_RANGE:")
print(current_app['INCOME_RANGE'].describe())
# Unique Values
print("\nUnique Values in INCOME_RANGE:")
print(current_app['INCOME_RANGE'].nunique())
# Out:
# Summary Statistics for INCOME_RANGE:
# count     291057
# unique         4
# top        0-25%
# freq       95841
# Name: INCOME_RANGE, dtype: object
#
# Unique Values in INCOME_RANGE:
# 4

# %%
# List out all unique values in the 'NFLAG_INSURED_ON_APPROVAL' column
unique_values = current_app['INCOME_RANGE'].unique()

print("\nUnique Values in INCOME_RANGE:")
print(unique_values)
# Out:
# Unique Values in INCOME_RANGE:
# ['50%-75%', '75%-100%', '0-25%', '25%-50%']
# Categories (4, object): ['0-25%' < '25%-50%' < '50%-75%' < '75%-100%']

# %%
NAME_CONTRACT = {
    'Cash loans': 1,
    'Revolving loans': 2
}
current_app['NAME_CONTRACT_TYPE'] = current_app['NAME_CONTRACT_TYPE'].replace(NAME_CONTRACT)

CODE_GENDER = {
    'M': 0,
    'F': 1,
    'Not prefer to say':2
}
current_app['CODE_GENDER'] = current_app['CODE_GENDER'].replace(CODE_GENDER)

FLAG_OWN_CAR = {
    'Y': 0,
    'N': 1
}

NAME_SUITE = {
    'Unaccompanied':1,
    'Spouse, partner':2,
    'Family':3,
    'Children':4,
    'Group of people':5,
    'Other_A':6,
    'Other_B':7,
    'Unknown':8
}
current_app['NAME_TYPE_SUITE'] = current_app['NAME_TYPE_SUITE'].replace(NAME_SUITE)

NAME_INCOME = {
    'Working':1,
    'State servant':2,
    'Commercial associate':3,
    'Businessman':4,
    'Pensioner':5,
    'Maternity leave':6,
    'Unemployed':7,
    'Student':8
}
current_app['NAME_INCOME_TYPE'] = current_app['NAME_INCOME_TYPE'].replace(NAME_INCOME)


NAME_EDUCATION_TYPE = {
    'Academic degree':1,
    'Higher education':2,
    'Lower secondary':3,
    'Secondary / secondary special':4,
    'Incomplete higher':5
}
current_app['NAME_EDUCATION_TYPE'] = current_app['NAME_EDUCATION_TYPE'].replace(NAME_EDUCATION_TYPE)

NAME_FAMILY_STATUS = {
    'Single / not married':1,
    'Married':2,
    'Civil marriage':3,
    'Widow':4,
    'Separated':5,
    'Unknown':6
}
current_app['NAME_FAMILY_STATUS'] = current_app['NAME_FAMILY_STATUS'].replace(NAME_FAMILY_STATUS)

NAME_HOUSING_TYPE = {
    'Rented apartment':1,
    'With parents':2,
    'House / apartment':3,
    'Municipal apartment':4,
    'Co-op apartment':5,
    'Office apartment':6
}
current_app['NAME_HOUSING_TYPE'] = current_app['NAME_HOUSING_TYPE'].replace(NAME_HOUSING_TYPE)

OCCUPATION = {
    'Laborers':1,
    'Core staff':2,
    'Accountants':3,
    'Managers':4,
    'Drivers':5,
    'Sales staff':6,
    'Cleaning staff':7,
    'Cooking staff':8,
    'Private service staff':9,
    'Medicine staff':10,
    'Security staff':11,
    'High skill tech staff':12,
    'Waiters/barmen staff':13,
    'Low-skill Laborers':14,
    'Realty agents':15,
    'Secretaries':16,
    'IT staff':17,
    'HR staff':18,
    'Unknown':19
}
current_app['OCCUPATION_TYPE'] = current_app['OCCUPATION_TYPE'].replace(OCCUPATION)

WEEKDAY_APPR_PROCESS = {
    'MONDAY': 1,
    'TUESDAY': 2,
    'WEDNESDAY': 3,
    'THURSDAY': 4,
    'FRIDAY': 5,
    'SATURDAY': 6,
    'SUNDAY': 7
}
current_app['WEEKDAY_APPR_PROCESS_START'] = current_app['WEEKDAY_APPR_PROCESS_START'].replace(WEEKDAY_APPR_PROCESS)

ORGANIZATION_TYPE = {
    'Business Entity Type 3':1,'School':2, 'Government':3, 'Religion':4,
 'Electricity':5, 'Medicine':6, 'Business Entity Type 2':7, 'Self-employed':8,
 'Transport: type 2':9, 'Construction':10, 'Housing':11, 'Kindergarten':12,
 'Trade: type 7':13, 'Industry: type 11':14, 'Military':15, 'Services':16,
 'Security Ministries':17, 'Transport: type 4':18, 'Industry: type 1':19, 'Emergency':20,
 'Security':21, 'Trade: type 2':22, 'University':23, 'Transport: type 3':24, 'Police':25,
 'Business Entity Type 1':26, 'Postal':27, 'Industry: type 4':28, 'Agriculture':29,
 'Restaurant':30, 'Culture':31, 'Hotel':32, 'Industry: type 7':33, 'Trade: type 3':34,
 'Industry: type 3':35, 'Bank':36, 'Industry: type 9':37, 'Insurance':38, 'Trade: type 6':39,
 'Industry: type 2':40, 'Transport: type 1':41, 'Industry: type 12':42, 'Mobile':43,
 'Trade: type 1':44, 'Industry: type 5':45, 'Industry: type 10':46, 'Legal Services':47,
 'Advertising':48, 'Trade: type 5':49, 'Cleaning':50, 'Industry: type 13':51,
 'Trade: type 4':52, 'Telecom':53, 'Industry: type 8':54, 'Realtor':55, 'Industry: type 6':56,'Other':57, 'XNA':58
}
current_app['ORGANIZATION_TYPE'] = current_app['ORGANIZATION_TYPE'].replace(ORGANIZATION_TYPE)

Income_Category = {
    'High': 1,
    'Lower-Mid': 2,
    'Mid': 3,
    'Upper-Mid': 4,
    'Low': 5
}
current_app['Income_Category'] = current_app['Income_Category'].replace(Income_Category)

INCOME_RANGE = {
    '0-25%': 1,
    '25%-50%': 2,
    '50%-75%': 3,
    '75%-100%': 4,
}
current_app['INCOME_RANGE'] = current_app['INCOME_RANGE'].replace(INCOME_RANGE)

# %%
current_app.head()
# Out:
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  CNT_CHILDREN  \
# 0      100002       1                   1            0             0
# 1      100003       0                   1            1             0
# 2      100004       0                   2            0             0
# 3      100006       0                   1            1             0
# 4      100007       0                   1            0             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0          202500.0    406597.5      24700.5         351000.0
# 1          270000.0   1293502.5      35698.5        1129500.0
# 2           67500.0    135000.0       6750.0         135000.0
# 3          135000.0    312682.5      29686.5         297000.0
# 4          121500.0    513000.0      21865.5         513000.0
#
#    NAME_TYPE_SUITE  ...  OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# 0                1  ...                1              1.0
# ...

# %%
# Display column names
print("\nColumns in previous_app dataset:")
print(current_app.columns)
# Out:
# Columns in previous_app dataset:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
#        'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'DAYS_EMPLOYED', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY',
#        'WEEKDAY_APPR_PROCESS_START', 'REG_CITY_NOT_WORK_CITY',
#        'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'Income_Category',
#        'INCOME_RANGE'],
#       dtype='object')

# %%
# Select relevant columns
cols = ['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
        'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
       'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE',
       'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
       'NAME_HOUSING_TYPE',
       'DAYS_EMPLOYED',
       'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT',
       'REGION_RATING_CLIENT_W_CITY', 'WEEKDAY_APPR_PROCESS_START',
        'REG_CITY_NOT_WORK_CITY',
       'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE',
       'Income_Category', 'INCOME_RANGE']


# Filter the DataFrame to include only the relevant columns
df_set_1 = current_app[cols]

# Compute the correlation matrix
correlation_matrix_1 = df_set_1.corr()

# Plot the heatmap
plt.figure(figsize=(24, 20))  # Adjust the size as needed
sns.heatmap(correlation_matrix_1, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# CNT_CHILDREN Vs CNT_FAM_MEMBERS
# AMT_CREDIT' VS 'AMT_ANNUITY'Vs 'AMT_GOODS_PRICE
# NAME_INCOME_TYPE Vs DAYS_EMPLOYED Vs ORGANIZATION_TYPE
# ORGANIZATION_TYPE VS NAME_INCOME_TYPE
# REGION_RATING_CLIENT' VS 'REGION_RATING_CLIENT_W_CITY
# REG_CITY_NOT_WORK_CITY' VS 'LIVE_CITY_NOT_WORK_CITY' (positive)

# %%
# Select relevant columns
cols = ['CNT_CHILDREN', 'AMT_INCOME_TOTAL',
       'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
       'NAME_INCOME_TYPE','DAYS_EMPLOYED',
       'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT',
       'REGION_RATING_CLIENT_W_CITY', 'REG_CITY_NOT_WORK_CITY',
       'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE',
        ]


# Filter the DataFrame to include only the relevant columns
df_set_1 = current_app[cols]

# Compute the correlation matrix
correlation_matrix_1 = df_set_1.corr()

# Plot the heatmap
plt.figure(figsize=(10, 10))  # Adjust the size as needed
sns.heatmap(correlation_matrix_1, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
numerical_columns = [
    'CNT_CHILDREN','CNT_FAM_MEMBERS', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE','NAME_INCOME_TYPE',
    'DAYS_EMPLOYED','ORGANIZATION_TYPE','NAME_INCOME_TYPE','REGION_RATING_CLIENT' ,'REG_CITY_NOT_WORK_CITY',
    'LIVE_CITY_NOT_WORK_CITY'
]

plt.figure(figsize=(20, 15))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(5, 4, i)
    sns.boxplot(x=current_app[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
# Define a function to cap outliers using the IQR method
def cap_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Cap the values outside the bounds
    df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
    df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])

    return df

# List of columns to apply outlier capping
columns_to_cap = ['AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'DAYS_EMPLOYED', 'REGION_RATING_CLIENT']

# Apply the outlier capping function to each relevant column
for col in columns_to_cap:
    current_app = cap_outliers(current_app, col)

# Display the first few rows to ensure outliers have been capped
print(current_app[columns_to_cap].head())
# Out:
#    AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  DAYS_EMPLOYED  \
# 0    406597.5      24700.5         351000.0          637.0
# 1   1293502.5      35698.5        1129500.0         1188.0
# 2    135000.0       6750.0         135000.0          225.0
# 3    312682.5      29686.5         297000.0         3039.0
# 4    513000.0      21865.5         513000.0         3038.0
#
#    REGION_RATING_CLIENT
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   2.0
# 4                   2.0

# %%
current_app.head()
# Out:
#    SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  CNT_CHILDREN  \
# 0      100002       1                   1            0             0
# 1      100003       0                   1            1             0
# 2      100004       0                   2            0             0
# 3      100006       0                   1            1             0
# 4      100007       0                   1            0             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 0          202500.0    406597.5      24700.5         351000.0
# 1          270000.0   1293502.5      35698.5        1129500.0
# 2           67500.0    135000.0       6750.0         135000.0
# 3          135000.0    312682.5      29686.5         297000.0
# 4          121500.0    513000.0      21865.5         513000.0
#
#    NAME_TYPE_SUITE  ...  OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# 0                1  ...                1              1.0
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline  # Import Pipeline
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE  # Import SMOTE for handling class imbalance

# Define features and target
features = [
    'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'CNT_CHILDREN',
    'NAME_INCOME_TYPE', 'AMT_INCOME_TOTAL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
    'DAYS_EMPLOYED', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY',
    'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE'
]

target = 'TARGET'

# Split the dataset into features and target
X = current_app[features]
y = current_app[target]

# Split the dataset into training (70%) and testing + validation (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, stratify=y)
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# Apply SMOTE only to the training set to handle class imbalance
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Define preprocessor for pipeline
categorical_features = ['NAME_INCOME_TYPE', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE']
numeric_features = [feature for feature in features if feature not in categorical_features]

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_features),
        ('cat', OneHotEncoder(), categorical_features)
    ])

# Updated models with the best hyperparameters
models = {
    "Logistic Regression": Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', LogisticRegression(
            random_state=42,
            class_weight='balanced',
            max_iter=500,
            C=10,  # Best C value
            penalty='l2',  # Best penalty
            solver='liblinear'  # Best solver
        ))
    ]),
    "Decision Tree": Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', DecisionTreeClassifier(
            random_state=42,
            class_weight='balanced',
            max_depth=15,  # Best max_depth
            min_samples_split=2,  # Best min_samples_split
            min_samples_leaf=1  # Best min_samples_leaf
        ))
    ]),
    "Gradient Boosting": Pipeline(steps=[
        ('preprocessor', preprocessor),
        ('classifier', GradientBoostingClassifier(
            random_state=42,
            n_estimators=100  # This can be tuned further if needed
        ))
    ])
}

# %%
# @title Train and evaluate models using only the SMOTE-augmented training set

for name, model in models.items():
    model.fit(X_train_smote, y_train_smote)  # Train the model with the SMOTE training data
    y_train_pred = model.predict(X_train_smote)  # Predict on the training set

    print(f"\n{name} - Training Set Evaluation")
    print("Confusion Matrix :")
    print(confusion_matrix(y_train_smote, y_train_pred))

    print("Classification Report :")
    print(classification_report(y_train_smote, y_train_pred))

    print("Accuracy :", accuracy_score(y_train_smote, y_train_pred))

    # Check if the model has the predict_proba method for AUC and ROC curve
    if hasattr(model, "predict_proba"):
        y_train_pred_proba = model.predict_proba(X_train_smote)[:, 1]  # Probabilities for the positive class
        auc_score = roc_auc_score(y_train_smote, y_train_pred_proba)
        print("AUC :", auc_score)

        # Plot ROC curve
        fpr, tpr, _ = roc_curve(y_train_smote, y_train_pred_proba)
        plt.figure(figsize=(6, 6))
        plt.plot(fpr, tpr, color='orange', label=f'ROC (AUC = {auc_score:.2f})', linewidth=2)
        plt.plot([0, 1], [0, 1], linestyle='--', color='blue', label='Random Classifier')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'Receiver Operating Characteristic (ROC) Curve - {name}')
        plt.legend(loc="lower right")
        plt.show()
    else:
        print("AUC: Not applicable for this model")
# Out:
# Logistic Regression - Training Set Evaluation
# Confusion Matrix :
# [[126329  33998]
#  [ 40561 119766]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77    160327
#            1       0.78      0.75      0.76    160327
#
#     accuracy                           0.77    320654
#    macro avg       0.77      0.77      0.77    320654
# weighted avg       0.77      0.77      0.77    320654
#
# Accuracy : 0.7674783411402946
# AUC : 0.8393667657804622
# Decision Tree - Training Set Evaluation
# Confusion Matrix :
# [[148243  12084]
#  [ 32021 128306]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87    160327
#            1       0.91      0.80      0.85    160327
#
#     accuracy                           0.86    320654
#    macro avg       0.87      0.86      0.86    320654
# ...

# %%
# @title Cross-validation
from sklearn.model_selection import cross_val_score, cross_val_predict, StratifiedKFold

# Define cross-validation strategy (StratifiedKFold for class balance)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Perform cross-validation for each model
for name, model in models.items():
    scores = cross_val_score(model, X_val, y_val, cv=cv, scoring='accuracy')
    y_pred_cv = cross_val_predict(model, X_val, y_val, cv=cv)

    print(f"\n{name} - Cross-Validation:")
    print("Cross-validated Accuracy:", scores.mean(), "+/-", scores.std() * 2)

    # Evaluate classification report during cross-validation
    print("Classification Report (Cross-Validation):")
    print(classification_report(y_val, y_pred_cv))
# Out:
# Logistic Regression - Cross-Validation:
# Cross-validated Accuracy: 0.5933757422823944 +/- 0.0075820498943426125
# Classification Report (Cross-Validation):
#               precision    recall  f1-score   support
#
#            0       0.94      0.59      0.73     53419
#            1       0.12      0.61      0.20      4792
#
#     accuracy                           0.59     58211
#    macro avg       0.53      0.60      0.46     58211
# weighted avg       0.88      0.59      0.68     58211
#
#
# Decision Tree - Cross-Validation:
# Cross-validated Accuracy: 0.6512510206177737 +/- 0.04219899333009701
# Classification Report (Cross-Validation):
#               precision    recall  f1-score   support
#
#            0       0.93      0.67      0.78     53419
#            1       0.11      0.46      0.18      4792
#
#     accuracy                           0.65     58211
#    macro avg       0.52      0.56      0.48     58211
# weighted avg       0.86      0.65      0.73     58211
#
#
# ...

# %%
# @title  test the model with test data set(unseen)

for name, model in models.items():
    y_test_pred = model.predict(X_test)
    print(f"\n{name} - Test Set Evaluation:")

    # Confusion Matrix
    print("Confusion Matrix (Test Set):")
    print(confusion_matrix(y_test, y_test_pred))

    # Classification Report
    print("Classification Report (Test Set):")
    print(classification_report(y_test, y_test_pred))

    print("Accuracy (Test Set):", accuracy_score(y_test, y_test_pred))

    # AUC score on the test set (if the model supports probability prediction)
    if hasattr(model, "predict_proba"):
        y_test_pred_proba = model.predict_proba(X_test)[:, 1]
        auc_score_test = roc_auc_score(y_test, y_test_pred_proba)
        print(f"AUC (Test Set): {auc_score_test:.2f}")
    else:
        print("AUC: Not applicable for this model")
# Out:
# Logistic Regression - Test Set Evaluation:
# Confusion Matrix (Test Set):
# [[42098 11368]
#  [ 3627  1119]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85     53466
#            1       0.09      0.24      0.13      4746
#
#     accuracy                           0.74     58212
#    macro avg       0.51      0.51      0.49     58212
# weighted avg       0.85      0.74      0.79     58212
#
# Accuracy (Test Set): 0.7424070638356353
# AUC (Test Set): 0.52
#
# Decision Tree - Test Set Evaluation:
# Confusion Matrix (Test Set):
# [[48926  4540]
#  [ 4325   421]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     53466
#            1       0.08      0.09      0.09      4746
#
#     accuracy                           0.85     58212
#    macro avg       0.50      0.50      0.50     58212
# ...
